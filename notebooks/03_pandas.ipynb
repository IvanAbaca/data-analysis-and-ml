# %% [markdown]
# # Pandas Basics
#
# Ejercicios introductorios de Pandas. Resolver de a uno.

# %% [markdown]
# ---
#
# ## Ejercicio 1 — Crear una Series
#
# Importá Pandas como `pd`. Creá una `Series` a partir de `[10, 20, 30, 40, 50]` y mostrá la serie completa y el tipo del objeto.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 2 — Índices de una Series
#
# Creá una `Series` con valores `[80, 90, 75]` e índices `["Ana", "Ivan", "Lucas"]`. Mostrá la serie y el valor de `"Ivan"`.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 3 — Crear un DataFrame
#
# Creá un `DataFrame` con columnas `name`, `age` y `score` para tres personas. Mostralo y mostrà su tipo.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 4 — Inspección básica
#
# Mostrá las primeras filas con `head()`, su `shape` y los nombres de sus columnas.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 5 — Seleccionar una columna
#
# Seleccioná una columna y mostrá su contenido y el tipo de objeto devuelto.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 6 — Seleccionar varias columnas
#
# Seleccioná dos columnas al mismo tiempo y comprobá el tipo de objeto devuelto.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 7 — `iloc`: selección por posición
#
# Usá `iloc` para seleccionar una fila por posición y un valor indicando fila y columna por posición.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 8 — `loc`: selección por etiqueta
#
# Usá índices personalizados y `loc` para seleccionar una fila por etiqueta y un valor por etiqueta de fila y nombre de columna.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 9 — Slicing
#
# Usá `iloc` para obtener un subconjunto de filas y columnas.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 10 — Filtros
#
# Conservá únicamente las filas que cumplan una condición numérica.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 11 — Múltiples condiciones
#
# Filtrá combinando dos condiciones sobre las columnas.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 12 — Agregaciones
#
# Calculá suma, media, mínimo y máximo sobre una columna numérica.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 13 — Crear una columna
#
# Creá una nueva columna a partir de una operación sobre una columna existente.

# %%
# TODO

# %% [markdown]
# ---
#
# ## Ejercicio 14 — Resumen del DataFrame
#
# Obtené información general y estadísticas descriptivas del DataFrame.

# %%
# TODO
